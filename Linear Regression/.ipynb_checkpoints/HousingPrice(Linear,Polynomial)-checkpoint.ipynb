# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('kc_house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955             0    98178  47.5112 -122.257
# 1            400      1951          1991    98125  47.7210 -122.319
# 2              0      1933             0    98028  47.7379 -122.233
# 3            910      1965             0    98136  47.5208 -122.393
# 4              0      1987             0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503
#
# [5 rows x 21 columns]

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row0_col0 {
#             background-color:  #b40426;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row0_col1 {
#             background-color:  #445acc;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row0_col2 {
#             background-color:  #6485ec;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row0_col3 {
#             background-color:  #7295f4;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row0_col4 {
#             background-color:  #6b8df0;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row0_col5 {
#             background-color:  #3b4cc0;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row0_col6 {
#             background-color:  #84a7fc;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row0_col7 {
#             background-color:  #455cce;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row0_col8 {
#             background-color:  #5470de;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row0_col9 {
#             background-color:  #8caffe;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row0_col10 {
#             background-color:  #6e90f2;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row0_col11 {
#             background-color:  #7a9df8;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row0_col12 {
#             background-color:  #799cf8;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row0_col13 {
#             background-color:  #97b8ff;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row0_col14 {
#             background-color:  #7093f3;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row0_col15 {
#             background-color:  #b1cbfc;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row0_col16 {
#             background-color:  #6282ea;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row0_col17 {
#             background-color:  #b7cff9;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row0_col18 {
#             background-color:  #81a4fb;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row0_col19 {
#             background-color:  #3c4ec2;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row1_col0 {
#             background-color:  #5b7ae5;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row1_col1 {
#             background-color:  #b40426;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row1_col2 {
#             background-color:  #c0d4f5;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row1_col3 {
#             background-color:  #f2c9b4;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row1_col4 {
#             background-color:  #f4987a;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row1_col5 {
#             background-color:  #7a9df8;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row1_col6 {
#             background-color:  #c4d5f3;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row1_col7 {
#             background-color:  #9dbdff;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row1_col8 {
#             background-color:  #ccd9ed;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row1_col9 {
#             background-color:  #9bbcff;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row1_col10 {
#             background-color:  #f6a586;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row1_col11 {
#             background-color:  #f7b194;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row1_col12 {
#             background-color:  #d2dbe8;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row1_col13 {
#             background-color:  #a1c0ff;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row1_col14 {
#             background-color:  #9abbff;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row1_col15 {
#             background-color:  #a7c5fe;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row1_col16 {
#             background-color:  #bfd3f6;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row1_col17 {
#             background-color:  #b7cff9;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row1_col18 {
#             background-color:  #f7b497;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row1_col19 {
#             background-color:  #7b9ff9;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row2_col0 {
#             background-color:  #6180e9;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row2_col1 {
#             background-color:  #adc9fd;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row2_col2 {
#             background-color:  #b40426;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row2_col3 {
#             background-color:  #f2cbb7;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row2_col4 {
#             background-color:  #f6bea4;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row2_col5 {
#             background-color:  #688aef;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row2_col6 {
#             background-color:  #aec9fc;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row2_col7 {
#             background-color:  #445acc;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row2_col8 {
#             background-color:  #688aef;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row2_col9 {
#             background-color:  #9abbff;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row2_col10 {
#             background-color:  #d2dbe8;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row2_col11 {
#             background-color:  #efcebd;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row2_col12 {
#             background-color:  #ccd9ed;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row2_col13 {
#             background-color:  #b9d0f9;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row2_col14 {
#             background-color:  #7a9df8;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row2_col15 {
#             background-color:  #92b4fe;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row2_col16 {
#             background-color:  #6180e9;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row2_col17 {
#             background-color:  #cdd9ec;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row2_col18 {
#             background-color:  #e3d9d3;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row2_col19 {
#             background-color:  #6b8df0;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row3_col0 {
#             background-color:  #6282ea;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row3_col1 {
#             background-color:  #e9d5cb;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row3_col2 {
#             background-color:  #efcfbf;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row3_col3 {
#             background-color:  #b40426;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row3_col4 {
#             background-color:  #ee8669;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row3_col5 {
#             background-color:  #799cf8;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row3_col6 {
#             background-color:  #f2cab5;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row3_col7 {
#             background-color:  #5977e3;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row3_col8 {
#             background-color:  #8caffe;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row3_col9 {
#             background-color:  #7295f4;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row3_col10 {
#             background-color:  #f7a688;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row3_col11 {
#             background-color:  #f4987a;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row3_col12 {
#             background-color:  #c7d7f0;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row3_col13 {
#             background-color:  #f5c0a7;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row3_col14 {
#             background-color:  #84a7fc;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d2441ed9c1row3_col15 {
#             background-color:  #85a8fc;
#         }    #T_8416fe80_b9af_11e9_8f7a_28d

# %%
df.corr()['price']
# Out:
# id              -0.016762
# price            1.000000
# bedrooms         0.308350
# bathrooms        0.525138
# sqft_living      0.702035
# sqft_lot         0.089661
# floors           0.256794
# waterfront       0.266369
# view             0.397293
# condition        0.036362
# grade            0.667434
# sqft_above       0.605567
# sqft_basement    0.323816
# yr_built         0.054012
# yr_renovated     0.126434
# zipcode         -0.053203
# lat              0.307003
# long             0.021626
# sqft_living15    0.585379
# sqft_lot15       0.082447
# Name: price, dtype: float64

# %%
fd  = df[['sqft_living','grade','sqft_above','sqft_living15','bathrooms']]
fd.head()
# Out:
#    sqft_living  grade  sqft_above  sqft_living15  bathrooms
# 0         1180      7        1180           1340       1.00
# 1         2570      7        2170           1690       2.25
# 2          770      6         770           2720       1.00
# 3         1960      7        1050           1360       3.00
# 4         1680      8        1680           1800       2.00

# %%
fd.describe()
# Out:
#         sqft_living         grade    sqft_above  sqft_living15     bathrooms
# count  21613.000000  21613.000000  21613.000000   21613.000000  21613.000000
# mean    2079.899736      7.656873   1788.390691    1986.552492      2.114757
# std      918.440897      1.175459    828.090978     685.391304      0.770163
# min      290.000000      1.000000    290.000000     399.000000      0.000000
# 25%     1427.000000      7.000000   1190.000000    1490.000000      1.750000
# 50%     1910.000000      7.000000   1560.000000    1840.000000      2.250000
# 75%     2550.000000      8.000000   2210.000000    2360.000000      2.500000
# max    13540.000000     13.000000   9410.000000    6210.000000      8.000000

# %%
df.plot.hist(alpha=0.5)

# %%
pd.plotting.scatter_matrix(df[['sqft_living','grade','sqft_above','sqft_living15','bathrooms','price']],alpha=0.2,figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000208F0678D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F2317A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1AD3FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1AECFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1B0E1D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1B0E208>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1B4D6D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1B6E978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1B90C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1BB1EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1BDC198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1BFB438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1C1D6D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1C3B978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1C5CC18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1C80EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1CA7198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1CC9438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1CE96D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1D0A978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1D2BC18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1D4CEB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1D76198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1D97438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1DB66D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1DD6978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1DFAC18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1E1CEB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1E44198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1E65438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1E856D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1EA5978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1EC8C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1EE9EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1F13198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208F1F32438>]],
#       dtype=object)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(df[['sqft_living','grade','sqft_above','sqft_living15','bathrooms','price']])
# scaler['price']
# Out:
# C:\Users\PRINCE\Anaconda3\envs\Pandas\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
import sklearn 
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(fd,df['price'])

# %%
x_train.plot.hist(alpha=0.5)

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np
sc_X = StandardScaler()
x_train = sc_X.fit_transform(x_train)
x_test = sc_X.transform(x_test)
sc_y = StandardScaler()
y_train = sc_y.fit_transform(np.array(y_train).reshape(-1,1))
y_test = sc_y.transform(np.array(y_test).reshape(-1,1))

# %%
from sklearn.linear_model import LinearRegression
line = LinearRegression().fit(x_train,y_train)

# %%
from sklearn.metrics import r2_score
y_pred = line.predict(x_test)

# %%
plt.plot(y_test,y_pred,'bo')
plt.plot(y_test,y_test)

# %%
r2score = r2_score(y_test,y_pred)
r2score
# Out:
# 0.55056853259642

# %%
# 9652176468

from sklearn.preprocessing import PolynomialFeatures
plFtr = PolynomialFeatures(degree=3)
x_poly = plFtr.fit_transform(x_train)
x_testpoly = plFtr.fit_transform(x_test)

plFtr.fit(x_poly,y_train)
lnrg = LinearRegression().fit(x_poly,y_train)
y_predpoly = lnrg.predict(x_testpoly)

# %%
plt.plot(y_test,y_predpoly,'ro',alpha=0.5)
plt.plot(y_test,y_test)

# %%
r2score = r2_score(y_test,y_predpoly)

# %%
r2score
# Out:
# 0.6311182783857641

# %%
# 9652176468

from sklearn.preprocessing import PolynomialFeatures
plFtr = PolynomialFeatures(degree=3)
x_poly = plFtr.fit_transform(x_train)
x_testpoly = plFtr.fit_transform(x_test)

plFtr.fit(x_poly,y_train)
lnrg = LinearRegression().fit(x_poly,y_train)
y_predpoly = lnrg.predict(x_testpoly)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-62-50b3802a85b2> in <module>
# ----> 1 plt.plot(np.array(x_poly)[:, 0, 0],y_predpoly,'bo')
#
# IndexError: too many indices for array
